# %%
pip3 install pandas rapidfuzz rouge
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.11/dist-packages (3.12.1)
# Requirement already satisfied: rouge in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from rouge) (1.17.0)

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, pipeline
import json
import pandas as pd
from rapidfuzz import fuzz
from sklearn.metrics import precision_score, recall_score, f1_score
from sentence_transformers import SentenceTransformer, util  # Semantic similarity
from tqdm import tqdm
import numpy as np

from rouge import Rouge

import torch
print(torch.cuda.is_available())  # Should return True if GPU is available
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")

# Load the experiment JSON file
with open("./experiment_2.json", "r") as f:
    data = json.load(f)

contexts = data["contexts"]

#---------------------------------------------------------------------------------------------------------------------------------------


models = {
    "Jasu/legalbert": pipeline("question-answering",
        model=AutoModelForQuestionAnswering.from_pretrained("Jasu/bert-finetuned-squad-legalbert"),
        tokenizer=AutoTokenizer.from_pretrained("Jasu/bert-finetuned-squad-legalbert"),
        device=0 ), # Use GPU

    "deepset/roberta-squad2": pipeline("question-answering",
        model=AutoModelForQuestionAnswering.from_pretrained("deepset/roberta-base-squad2"),
        tokenizer=AutoTokenizer.from_pretrained("deepset/roberta-base-squad2"),
        device=0 ), # Use GPU

}


#---------------------------------------------------------------------------------------------------------------------------------------

def compute_em(prediction, gold):
    """
    Compute the Exact Match (EM) score. Returns 1 if prediction equals gold exactly, else 0.
    """
    return 1 if prediction.strip() == gold.strip() else 0

def compute_f1(prediction, gold):
    """
    Compute token-level F1 score for two strings.
    """
    pred_tokens = prediction.strip().split()
    gold_tokens = gold.strip().split()
    common = set(pred_tokens) & set(gold_tokens)
    if len(common) == 0:
        return 0
    precision = len(common) / len(pred_tokens)
    recall = len(common) / len(gold_tokens)
    return 2 * (precision * recall) / (precision + recall)

def compute_partial_f1(prediction, gold):
    """
    A partial F1 function can reward partial overlaps even if the token sets are not exactly matching.
    For this example, we define partial F1 as:
         partial_f1 = (number of overlapping tokens) / (average length of gold and prediction)
    """
    pred_tokens = prediction.strip().split()
    gold_tokens = gold.strip().split()
    common = set(pred_tokens) & set(gold_tokens)
    if len(common) == 0:
        return 0
    avg_length = (len(pred_tokens) + len(gold_tokens)) / 2.0
    return len(common) / avg_length

# Initialize a semantic similarity model from SentenceTransformers

semantic_model = SentenceTransformer('all-MiniLM-L6-v2', device='cuda')
def compute_semantic_similarity(prediction, gold):
    """
    Compute the cosine similarity between the embeddings of the prediction and gold answer.
    Returns a float between 0 and 1.
    """
    pred_embedding = semantic_model.encode(prediction, convert_to_tensor=True).to('cuda')
    gold_embedding = semantic_model.encode(gold, convert_to_tensor=True).to('cuda')
    cosine_sim = util.cos_sim(pred_embedding, gold_embedding).item()
    return cosine_sim

rouge = Rouge()

# ROUGE Score Calculation
def compute_rouge(prediction, gold):
    scores = rouge.get_scores(prediction, gold)
    return scores[0]['rouge-l']['f']  # Using ROUGE-L F1 score



qa_pipeline = pipeline("question-answering", model="deepset/roberta-base-squad2", device=0)
result = qa_pipeline({"question": "What is the capital of France?", "context": "Paris is the capital of France."})
print(result)


#---------------------------------------------------------------------------------------------------------------------------------------


# Run the Experiment

# { model_name: { category: [ { "Format": ..., "Question": ..., "Gold Answer": ..., "Model Answer": ..., metrics... }, ... ] } }

detailed_results = {}

for model_name, qa_model in models.items():
    detailed_results[model_name] = {}

    print(f"Running experiments for model: {model_name}")
    # Loop over each context

    for ctx_item in tqdm(data["contexts"], desc="Contexts"):
        context_text = ctx_item["context"]

        for category_dict in tqdm(ctx_item["Categories"], desc="Categories", leave=False):
            # Each category_dict key is the category name and value is a list of question objects.
            for cat_name, questions in category_dict.items():
                if cat_name not in detailed_results[model_name]:
                    detailed_results[model_name][cat_name] = []

                # Iterate over each question in the category
                for q_obj in tqdm(questions, desc=f"Questions in {cat_name}", leave=False):
                    format_type = q_obj["Format"]
                    question_text = q_obj["Question"]
                    gold_answer = q_obj["Gold Answer"]
                    # Run the QA model with the provided question and context
                    result = qa_model({"question": question_text, "context": context_text})
                    # Some pipelines return a dict; extract the "answer" if available
                    model_answer = result.get("answer", result) if isinstance(result, dict) else result

                    # Compute evaluation metrics
                    em = compute_em(model_answer, gold_answer)
                    f1 = compute_f1(model_answer, gold_answer)
                    partial_f1 = compute_partial_f1(model_answer, gold_answer)
                    rouge_score = compute_rouge(model_answer, gold_answer)
                    semantic_sim = compute_semantic_similarity(model_answer, gold_answer)

                    # Save the detailed result for this question
                    detailed_results[model_name][cat_name].append({
                        "Format": format_type,
                        "Question": question_text,
                        "Gold Answer": gold_answer,
                        "Model Answer": model_answer,
                        "EM": em,
                        "F1": f1,
                        "Partial F1": partial_f1,
                        "ROUGE": rouge_score,
                        "Semantic Similarity": semantic_sim
                    })

# Save detailed results to a JSON file for further analysis
with open("detailed_experiment_results.json", "w") as outfile:
    json.dump(detailed_results, outfile, indent=2)


# Aggregate metrics by model and question format (across all contexts and categories)
aggregated_metrics = {}  # { model_name: { format: {metrics} } }
for model_name, cat_results in detailed_results.items():
    format_scores = {}
    for cat, results_list in cat_results.items():
        for entry in results_list:
            fmt = entry["Format"]
            if fmt not in format_scores:
                format_scores[fmt] = {"EM": [], "F1": [], "Partial F1": [], "ROUGE": [], "Semantic Similarity": []}
            format_scores[fmt]["EM"].append(entry["EM"])
            format_scores[fmt]["F1"].append(entry["F1"])
            format_scores[fmt]["Partial F1"].append(entry["Partial F1"])
            format_scores[fmt]["ROUGE"].append(entry["ROUGE"])
            format_scores[fmt]["Semantic Similarity"].append(entry["Semantic Similarity"])
    aggregated_metrics[model_name] = {}
    for fmt, scores in format_scores.items():
        aggregated_metrics[model_name][fmt] = {
            "Avg EM": np.mean(scores["EM"]),
            "Avg F1": np.mean(scores["F1"]),
            "Avg Partial F1": np.mean(scores["Partial F1"]),
            "Avg ROUGE": np.mean(scores["ROUGE"]),
            "Avg Semantic Similarity": np.mean(scores["Semantic Similarity"])
        }

with open("Aggregated_experiment_results.json", "w") as outfile:
    json.dump(aggregated_metrics, outfile, indent=2)
# Out:
# True
# Tesla T4
# Device set to use cuda:0
# Device set to use cuda:0
# Device set to use cuda:0
# {'score': 0.5974364280700684, 'start': 0, 'end': 5, 'answer': 'Paris'}
# Running experiments for model: Jasu/legalbert
# Contexts:   0%|          | 0/3 [00:00<?, ?it/s]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in Establishment of Distributorship:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Establishment of Distributorship:  25%|██▌       | 1/4 [00:01<00:03,  1.08s/it]
#
# Questions in Establishment of Distributorship:  50%|█████     | 2/4 [00:02<00:02,  1.01s/it]
#
# Questions in Establishment of Distributorship:  75%|███████▌  | 3/4 [00:02<00:00,  1.04it/s]
#
# Questions in Establishment of Distributorship: 100%|██████████| 4/4 [00:03<00:00,  1.01it/s]
#
#
#
# Questions in Term of the Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Term of the Agreement:  25%|██▌       | 1/4 [00:00<00:02,  1.18it/s]
#
# Questions in Term of the Agreement:  50%|█████     | 2/4 [00:02<00:02,  1.28s/it]
#
# Questions in Term of the Agreement:  75%|███████▌  | 3/4 [00:04<00:01,  1.58s/it]
#
# Questions in Term of the Agreement: 100%|██████████| 4/4 [00:05<00:00,  1.56s/it]
#
#
#
# Questions in Minimum Purchase Requirements:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Minimum Purchase Requirements:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
#
# Questions in Minimum Purchase Requirements:  50%|█████     | 2/4 [00:01<00:01,  1.15it/s]
#
# Questions in Minimum Purchase Requirements:  75%|███████▌  | 3/4 [00:02<00:00,  1.17it/s]
#
# Questions in Minimum Purchase Requirements: 100%|██████████| 4/4 [00:03<00:00,  1.16it/s]
#
#
#
# Questions in Warranty Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Warranty Terms:  25%|██▌       | 1/4 [00:00<00:02,  1.23it/s]
#
# Questions in Warranty Terms:  50%|█████     | 2/4 [00:01<00:01,  1.16it/s]
#
# Questions in Warranty Terms:  75%|███████▌  | 3/4 [00:02<00:00,  1.07it/s]
#
# Questions in Warranty Terms: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
#
#
#
# Questions in Termination Conditions:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Termination Conditions:  25%|██▌       | 1/4 [00:01<00:03,  1.05s/it]
#
# Questions in Termination Conditions:  50%|█████     | 2/4 [00:01<00:01,  1.05it/s]
#
# Questions in Termination Conditions:  75%|███████▌  | 3/4 [00:02<00:00,  1.16it/s]
#
# Questions in Termination Conditions: 100%|██████████| 4/4 [00:05<00:00,  1.46s/it]
#
#
#
# Questions in Payment Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Payment Terms:  25%|██▌       | 1/4 [00:00<00:02,  1.30it/s]
#
# Questions in Payment Terms:  50%|█████     | 2/4 [00:01<00:01,  1.27it/s]
#
# Questions in Payment Terms:  75%|███████▌  | 3/4 [00:02<00:00,  1.32it/s]
#
# Questions in Payment Terms: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s]
#
#
#
# Questions in Indemnification Obligations:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Indemnification Obligations:  25%|██▌       | 1/4 [00:00<00:02,  1.33it/s]
#
# Questions in Indemnification Obligations:  50%|█████     | 2/4 [00:01<00:01,  1.28it/s]
#
# Questions in Indemnification Obligations:  75%|███████▌  | 3/4 [00:02<00:00,  1.33it/s]
#
# Questions in Indemnification Obligations: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s]
#
#
#
# Questions in Non-Disclosure Agreements:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Non-Disclosure Agreements:  25%|██▌       | 1/4 [00:00<00:02,  1.36it/s]
#
# Questions in Non-Disclosure Agreements:  50%|█████     | 2/4 [00:01<00:01,  1.27it/s]
#
# Questions in Non-Disclosure Agreements:  75%|███████▌  | 3/4 [00:02<00:00,  1.31it/s]
#
# Questions in Non-Disclosure Agreements: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s]
#
#
#
# Questions in Relationship of Parties:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Relationship of Parties:  25%|██▌       | 1/4 [00:00<00:02,  1.33it/s]
#
# Questions in Relationship of Parties:  50%|█████     | 2/4 [00:01<00:01,  1.22it/s]
#
# Questions in Relationship of Parties:  75%|███████▌  | 3/4 [00:02<00:00,  1.22it/s]
#
# Questions in Relationship of Parties: 100%|██████████| 4/4 [00:03<00:00,  1.19it/s]
#
#
#
# Questions in License Grant:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in License Grant:  25%|██▌       | 1/4 [00:00<00:02,  1.22it/s]
#
# Questions in License Grant:  50%|█████     | 2/4 [00:01<00:01,  1.22it/s]
#
# Questions in License Grant:  75%|███████▌  | 3/4 [00:02<00:00,  1.27it/s]
#
# Questions in License Grant: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s]
#
#
# Categories: 100%|██████████| 1/1 [00:38<00:00, 38.40s/it]
# Contexts:  33%|███▎      | 1/3 [00:38<01:16, 38.41s/it]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in License Grants and Restrictions:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in License Grants and Restrictions:  25%|██▌       | 1/4 [00:01<00:04,  1.46s/it]
#
# Questions in License Grants and Restrictions:  50%|█████     | 2/4 [00:02<00:02,  1.47s/it]
#
# Questions in License Grants and Restrictions:  75%|███████▌  | 3/4 [00:04<00:01,  1.46s/it]
#
# Questions in License Grants and Restrictions: 100%|██████████| 4/4 [00:05<00:00,  1.49s/it]
#
#
#
# Questions in Distribution and Other Obligations:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Distribution and Other Obligations:  25%|██▌       | 1/4 [00:01<00:04,  1.49s/it]
#
# Questions in Distribution and Other Obligations:  50%|█████     | 2/4 [00:03<00:03,  1.53s/it]
#
# Questions in Distribution and Other Obligations:  75%|███████▌  | 3/4 [00:04<00:01,  1.54s/it]
#
# Questions in Distribution and Other Obligations: 100%|██████████| 4/4 [00:06<00:00,  1.55s/it]
#
#
#
# Questions in Payment Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Payment Terms:  25%|██▌       | 1/4 [00:01<00:04,  1.47s/it]
#
# Questions in Payment Terms:  50%|█████     | 2/4 [00:02<00:02,  1.47s/it]
#
# Questions in Payment Terms:  75%|███████▌  | 3/4 [00:04<00:01,  1.48s/it]
#
# Questions in Payment Terms: 100%|██████████| 4/4 [00:05<00:00,  1.51s/it]
#
#
#
# Questions in Term and Termination:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Term and Termination:  25%|██▌       | 1/4 [00:01<00:04,  1.45s/it]
#
# Questions in Term and Termination:  50%|█████     | 2/4 [00:02<00:02,  1.49s/it]
#
# Questions in Term and Termination:  75%|███████▌  | 3/4 [00:04<00:01,  1.55s/it]
#
# Questions in Term and Termination: 100%|██████████| 4/4 [00:06<00:00,  1.58s/it]
#
#
#
# Questions in Confidential Information:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Confidential Information:  25%|██▌       | 1/4 [00:01<00:04,  1.49s/it]
#
# Questions in Confidential Information:  50%|█████     | 2/4 [00:02<00:02,  1.48s/it]
#
# Questions in Confidential Information:  75%|███████▌  | 3/4 [00:04<00:01,  1.48s/it]
#
# Questions in Confidential Information: 100%|██████████| 4/4 [00:06<00:00,  1.51s/it]
#
#
#
# Questions in Proprietary Rights:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Proprietary Rights:  25%|██▌       | 1/4 [00:01<00:04,  1.53s/it]
#
# Questions in Proprietary Rights:  50%|█████     | 2/4 [00:03<00:03,  1.54s/it]
#
# Questions in Proprietary Rights:  75%|███████▌  | 3/4 [00:04<00:01,  1.57s/it]
#
# Questions in Proprietary Rights: 100%|██████████| 4/4 [00:06<00:00,  1.60s/it]
#
#
#
# Questions in Warranties:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Warranties:  25%|██▌       | 1/4 [00:01<00:04,  1.50s/it]
#
# Questions in Warranties:  50%|█████     | 2/4 [00:02<00:02,  1.49s/it]
#
# Questions in Warranties:  75%|███████▌  | 3/4 [00:04<00:01,  1.50s/it]
#
# Questions in Warranties: 100%|██████████| 4/4 [00:06<00:00,  1.52s/it]
#
#
#
# Questions in Limitation of Liability:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Limitation of Liability:  25%|██▌       | 1/4 [00:01<00:04,  1.51s/it]
#
# Questions in Limitation of Liability:  50%|█████     | 2/4 [00:02<00:02,  1.50s/it]
#
# Questions in Limitation of Liability:  75%|███████▌  | 3/4 [00:04<00:01,  1.53s/it]
#
# Questions in Limitation of Liability: 100%|██████████| 4/4 [00:06<00:00,  1.60s/it]
#
#
#
# Questions in Indemnification:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Indemnification:  25%|██▌       | 1/4 [00:01<00:04,  1.49s/it]
#
# Questions in Indemnification:  50%|█████     | 2/4 [00:02<00:02,  1.50s/it]
#
# Questions in Indemnification:  75%|███████▌  | 3/4 [00:04<00:01,  1.64s/it]
#
# Questions in Indemnification: 100%|██████████| 4/4 [00:07<00:00,  1.89s/it]
#
#
#
# Questions in General:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in General:  25%|██▌       | 1/4 [00:01<00:04,  1.49s/it]
#
# Questions in General:  50%|█████     | 2/4 [00:03<00:03,  1.52s/it]
#
# Questions in General:  75%|███████▌  | 3/4 [00:04<00:01,  1.56s/it]
#
# Questions in General: 100%|██████████| 4/4 [00:06<00:00,  1.61s/it]
#
#
# Categories: 100%|██████████| 1/1 [01:02<00:00, 62.48s/it]
# Contexts:  67%|██████▋   | 2/3 [01:40<00:52, 52.58s/it]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in Filing Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Filing Agreement:  75%|███████▌  | 3/4 [00:00<00:00, 27.22it/s]
#
#
#
# Questions in Regulatory Compliance:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Regulatory Compliance: 100%|██████████| 4/4 [00:00<00:00, 33.03it/s]
#
#
#
# Questions in Filing Responsibility:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Filing Responsibility: 100%|██████████| 4/4 [00:00<00:00, 31.80it/s]
#
#
#
# Questions in Accuracy of Information:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Accuracy of Information: 100%|██████████| 4/4 [00:00<00:00, 32.74it/s]
#
#
#
# Questions in Date of Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Date of Agreement: 100%|██████████| 4/4 [00:00<00:00, 34.29it/s]
#
#
#
# Questions in Signatories:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Signatories: 100%|██████████| 4/4 [00:00<00:00, 34.03it/s]
#
#
# Categories: 100%|██████████| 1/1 [00:00<00:00,  1.20it/s]
# Contexts: 100%|██████████| 3/3 [01:41<00:00, 33.92s/it]
# Running experiments for model: deepset/roberta-squad2
# Contexts:   0%|          | 0/3 [00:00<?, ?it/s]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in Establishment of Distributorship:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Establishment of Distributorship:  25%|██▌       | 1/4 [00:02<00:07,  2.38s/it]
#
# Questions in Establishment of Distributorship:  50%|█████     | 2/4 [00:05<00:05,  2.54s/it]
#
# Questions in Establishment of Distributorship:  75%|███████▌  | 3/4 [00:07<00:02,  2.45s/it]
#
# Questions in Establishment of Distributorship: 100%|██████████| 4/4 [00:10<00:00,  2.55s/it]
#
#
#
# Questions in Term of the Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Term of the Agreement:  25%|██▌       | 1/4 [00:02<00:07,  2.40s/it]
#
# Questions in Term of the Agreement:  50%|█████     | 2/4 [00:04<00:05,  2.50s/it]
#
# Questions in Term of the Agreement:  75%|███████▌  | 3/4 [00:07<00:02,  2.41s/it]
#
# Questions in Term of the Agreement: 100%|██████████| 4/4 [00:09<00:00,  2.43s/it]
#
#
#
# Questions in Minimum Purchase Requirements:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Minimum Purchase Requirements:  25%|██▌       | 1/4 [00:02<00:07,  2.37s/it]
#
# Questions in Minimum Purchase Requirements:  50%|█████     | 2/4 [00:05<00:05,  2.67s/it]
#
# Questions in Minimum Purchase Requirements:  75%|███████▌  | 3/4 [00:07<00:02,  2.56s/it]
#
# Questions in Minimum Purchase Requirements: 100%|██████████| 4/4 [00:10<00:00,  2.53s/it]
#
#
#
# Questions in Warranty Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Warranty Terms:  25%|██▌       | 1/4 [00:02<00:07,  2.36s/it]
#
# Questions in Warranty Terms:  50%|█████     | 2/4 [00:04<00:05,  2.51s/it]
#
# Questions in Warranty Terms:  75%|███████▌  | 3/4 [00:07<00:02,  2.48s/it]
#
# Questions in Warranty Terms: 100%|██████████| 4/4 [01:28<00:00, 33.54s/it]
#
#
#
# Questions in Termination Conditions:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Termination Conditions:  25%|██▌       | 1/4 [00:02<00:07,  2.47s/it]
#
# Questions in Termination Conditions:  50%|█████     | 2/4 [00:05<00:05,  2.55s/it]
#
# Questions in Termination Conditions:  75%|███████▌  | 3/4 [00:07<00:02,  2.43s/it]
#
# Questions in Termination Conditions: 100%|██████████| 4/4 [00:14<00:00,  4.42s/it]
#
#
#
# Questions in Payment Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Payment Terms:  25%|██▌       | 1/4 [00:02<00:07,  2.38s/it]
#
# Questions in Payment Terms:  50%|█████     | 2/4 [00:05<00:05,  2.53s/it]
#
# Questions in Payment Terms:  75%|███████▌  | 3/4 [00:07<00:02,  2.45s/it]
#
# Questions in Payment Terms: 100%|██████████| 4/4 [00:09<00:00,  2.51s/it]
#
#
#
# Questions in Indemnification Obligations:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Indemnification Obligations:  25%|██▌       | 1/4 [00:02<00:07,  2.51s/it]
#
# Questions in Indemnification Obligations:  50%|█████     | 2/4 [00:05<00:05,  2.61s/it]
#
# Questions in Indemnification Obligations:  75%|███████▌  | 3/4 [00:07<00:02,  2.52s/it]
#
# Questions in Indemnification Obligations: 100%|██████████| 4/4 [00:10<00:00,  2.52s/it]
#
#
#
# Questions in Non-Disclosure Agreements:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Non-Disclosure Agreements:  25%|██▌       | 1/4 [00:02<00:07,  2.51s/it]
#
# Questions in Non-Disclosure Agreements:  50%|█████     | 2/4 [00:05<00:05,  2.66s/it]
#
# Questions in Non-Disclosure Agreements:  75%|███████▌  | 3/4 [00:07<00:02,  2.53s/it]
#
# Questions in Non-Disclosure Agreements: 100%|██████████| 4/4 [00:10<00:00,  2.52s/it]
#
#
#
# Questions in Relationship of Parties:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Relationship of Parties:  25%|██▌       | 1/4 [00:02<00:07,  2.39s/it]
#
# Questions in Relationship of Parties:  50%|█████     | 2/4 [00:05<00:05,  2.61s/it]
#
# Questions in Relationship of Parties:  75%|███████▌  | 3/4 [00:07<00:02,  2.55s/it]
#
# Questions in Relationship of Parties: 100%|██████████| 4/4 [00:10<00:00,  2.52s/it]
#
#
#
# Questions in License Grant:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in License Grant:  25%|██▌       | 1/4 [00:02<00:07,  2.38s/it]
#
# Questions in License Grant:  50%|█████     | 2/4 [00:04<00:05,  2.51s/it]
#
# Questions in License Grant:  75%|███████▌  | 3/4 [00:07<00:02,  2.51s/it]
#
# Questions in License Grant: 100%|██████████| 4/4 [00:10<00:00,  2.56s/it]
#
#
# Categories: 100%|██████████| 1/1 [03:04<00:00, 184.02s/it]
# Contexts:  33%|███▎      | 1/3 [03:04<06:08, 184.03s/it]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in License Grants and Restrictions:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in License Grants and Restrictions:  25%|██▌       | 1/4 [00:01<00:05,  1.69s/it]
#
# Questions in License Grants and Restrictions:  50%|█████     | 2/4 [00:03<00:03,  1.68s/it]
#
# Questions in License Grants and Restrictions:  75%|███████▌  | 3/4 [00:05<00:01,  1.69s/it]
#
# Questions in License Grants and Restrictions: 100%|██████████| 4/4 [00:06<00:00,  1.71s/it]
#
#
#
# Questions in Distribution and Other Obligations:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Distribution and Other Obligations:  25%|██▌       | 1/4 [00:01<00:05,  1.68s/it]
#
# Questions in Distribution and Other Obligations:  50%|█████     | 2/4 [00:03<00:03,  1.72s/it]
#
# Questions in Distribution and Other Obligations:  75%|███████▌  | 3/4 [00:05<00:01,  1.79s/it]
#
# Questions in Distribution and Other Obligations: 100%|██████████| 4/4 [00:07<00:00,  1.79s/it]
#
#
#
# Questions in Payment Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Payment Terms:  25%|██▌       | 1/4 [00:01<00:04,  1.66s/it]
#
# Questions in Payment Terms:  50%|█████     | 2/4 [00:03<00:03,  1.65s/it]
#
# Questions in Payment Terms:  75%|███████▌  | 3/4 [00:04<00:01,  1.66s/it]
#
# Questions in Payment Terms: 100%|██████████| 4/4 [00:06<00:00,  1.69s/it]
#
#
#
# Questions in Term and Termination:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Term and Termination:  25%|██▌       | 1/4 [00:01<00:04,  1.63s/it]
#
# Questions in Term and Termination:  50%|█████     | 2/4 [00:03<00:03,  1.72s/it]
#
# Questions in Term and Termination:  75%|███████▌  | 3/4 [00:05<00:01,  1.73s/it]
#
# Questions in Term and Termination: 100%|██████████| 4/4 [00:06<00:00,  1.73s/it]
#
#
#
# Questions in Confidential Information:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Confidential Information:  25%|██▌       | 1/4 [00:01<00:05,  1.67s/it]
#
# Questions in Confidential Information:  50%|█████     | 2/4 [00:03<00:03,  1.67s/it]
#
# Questions in Confidential Information:  75%|███████▌  | 3/4 [00:04<00:01,  1.66s/it]
#
# Questions in Confidential Information: 100%|██████████| 4/4 [00:06<00:00,  1.70s/it]
#
#
#
# Questions in Proprietary Rights:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Proprietary Rights:  25%|██▌       | 1/4 [00:01<00:05,  1.76s/it]
#
# Questions in Proprietary Rights:  50%|█████     | 2/4 [00:03<00:03,  1.80s/it]
#
# Questions in Proprietary Rights:  75%|███████▌  | 3/4 [00:05<00:01,  1.79s/it]
#
# Questions in Proprietary Rights: 100%|██████████| 4/4 [00:07<00:00,  1.79s/it]
#
#
#
# Questions in Warranties:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Warranties:  25%|██▌       | 1/4 [00:01<00:04,  1.66s/it]
#
# Questions in Warranties:  50%|█████     | 2/4 [00:03<00:03,  1.67s/it]
#
# Questions in Warranties:  75%|███████▌  | 3/4 [00:04<00:01,  1.66s/it]
#
# Questions in Warranties: 100%|██████████| 4/4 [00:06<00:00,  1.69s/it]
#
#
#
# Questions in Limitation of Liability:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Limitation of Liability:  25%|██▌       | 1/4 [00:01<00:05,  1.81s/it]
#
# Questions in Limitation of Liability:  50%|█████     | 2/4 [00:03<00:03,  1.79s/it]
#
# Questions in Limitation of Liability:  75%|███████▌  | 3/4 [00:05<00:01,  1.74s/it]
#
# Questions in Limitation of Liability: 100%|██████████| 4/4 [00:06<00:00,  1.74s/it]
#
#
#
# Questions in Indemnification:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Indemnification:  25%|██▌       | 1/4 [00:01<00:04,  1.67s/it]
#
# Questions in Indemnification:  50%|█████     | 2/4 [00:03<00:03,  1.67s/it]
#
# Questions in Indemnification:  75%|███████▌  | 3/4 [00:05<00:01,  1.69s/it]
#
# Questions in Indemnification: 100%|██████████| 4/4 [00:06<00:00,  1.74s/it]
#
#
#
# Questions in General:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in General:  25%|██▌       | 1/4 [00:01<00:05,  1.80s/it]
#
# Questions in General:  50%|█████     | 2/4 [00:03<00:03,  1.75s/it]
#
# Questions in General:  75%|███████▌  | 3/4 [00:05<00:01,  1.70s/it]
#
# Questions in General: 100%|██████████| 4/4 [00:06<00:00,  1.71s/it]
#
#
# Categories: 100%|██████████| 1/1 [01:09<00:00, 69.02s/it]
# Contexts:  67%|██████▋   | 2/3 [04:13<01:56, 116.38s/it]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in Filing Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Filing Agreement: 100%|██████████| 4/4 [00:00<00:00, 32.45it/s]
#
#
#
# Questions in Regulatory Compliance:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Regulatory Compliance:  75%|███████▌  | 3/4 [00:00<00:00, 23.72it/s]
#
#
#
# Questions in Filing Responsibility:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Filing Responsibility: 100%|██████████| 4/4 [00:00<00:00, 32.60it/s]
#
#
#
# Questions in Accuracy of Information:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Accuracy of Information: 100%|██████████| 4/4 [00:00<00:00, 31.61it/s]
#
#
#
# Questions in Date of Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Date of Agreement: 100%|██████████| 4/4 [00:00<00:00, 32.66it/s]
#
#
#
# Questions in Signatories:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Signatories: 100%|██████████| 4/4 [00:00<00:00, 31.67it/s]
#
#
# Categories: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# Contexts: 100%|██████████| 3/3 [04:13<00:00, 84.65s/it]

# %%
with open("Aggregated_experiment_results.json", "w") as outfile:
    json.dump(aggregated_metrics, outfile, indent=2)
