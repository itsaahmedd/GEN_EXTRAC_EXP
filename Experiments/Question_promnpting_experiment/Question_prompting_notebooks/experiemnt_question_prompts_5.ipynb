# %%
pip install pandas rapidfuzz rouge
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting rouge
#   Downloading rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from rouge) (1.17.0)
# Downloading rapidfuzz-3.12.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 47.8 MB/s eta 0:00:00
# Downloading rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge, rapidfuzz
# Successfully installed rapidfuzz-3.12.1 rouge-1.0.1

# %%
import re, string
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, pipeline
import json
import pandas as pd
from rapidfuzz import fuzz
from sklearn.metrics import precision_score, recall_score, f1_score
from sentence_transformers import SentenceTransformer, util  # Semantic similarity
from tqdm import tqdm
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from rouge import Rouge

import torch
print(torch.cuda.is_available())  # Should return True if GPU is available
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU only")

# Load the experiment JSON file
with open("./experiment_3.json", "r") as f:
    data = json.load(f)

contexts = data["contexts"]

#---------------------------------------------------------------------------------------------------------------------------------------


models = {
    "Jasu/legalbert": pipeline("question-answering",
        model=AutoModelForQuestionAnswering.from_pretrained("Jasu/bert-finetuned-squad-legalbert"),
        tokenizer=AutoTokenizer.from_pretrained("Jasu/bert-finetuned-squad-legalbert"),
        max_answer_len=250,
        ),
    "deepset/roberta-squad2": pipeline("question-answering",
        model=AutoModelForQuestionAnswering.from_pretrained("deepset/roberta-base-squad2"),
        tokenizer=AutoTokenizer.from_pretrained("deepset/roberta-base-squad2"),
        max_answer_len=250,
        )

}


#---------------------------------------------------------------------------------------------------------------------------------------
# Normalization function to preprocess text before metric comparisons
def normalize_text(text):
    text = text.lower()  # lowercase
    text = text.translate(str.maketrans("", "", string.punctuation))  # remove punctuation
    text = re.sub(r"\s+", " ", text).strip()  # collapse whitespace
    return text


def compute_em(prediction, gold):
    """
    Compute the Exact Match (EM) score. Returns 1 if prediction equals gold exactly, else 0.
    """
    pred_norm = normalize_text(prediction)
    gold_norm = normalize_text(gold)
    return 1 if pred_norm == gold_norm else 0

def compute_f1(prediction, gold):
    """
    Compute token-level F1 score for two strings.
    """
    pred_norm = normalize_text(prediction)
    gold_norm = normalize_text(gold)
    pred_tokens = pred_norm.split()
    gold_tokens = gold_norm.split()
    common = set(pred_tokens) & set(gold_tokens)
    if len(common) == 0:
        return 0
    precision = len(common) / len(pred_tokens)
    recall = len(common) / len(gold_tokens)
    return 2 * (precision * recall) / (precision + recall)

def compute_partial_f1(prediction, gold):
    """
    A partial F1 function can reward partial overlaps even if the token sets are not exactly matching.
    For this example, we define partial F1 as:
         partial_f1 = (number of overlapping tokens) / (average length of gold and prediction)
    """
    pred_norm = normalize_text(prediction)
    gold_norm = normalize_text(gold)
    pred_tokens = pred_norm.split()
    gold_tokens = gold_norm.split()
    common = set(pred_tokens) & set(gold_tokens)
    if len(common) == 0:
        return 0
    avg_length = (len(pred_tokens) + len(gold_tokens)) / 2.0
    return len(common) / avg_length

#Initialize a semantic similarity model from SentenceTransformers
semantic_model = SentenceTransformer('all-MiniLM-L6-v2')

def compute_semantic_similarity(prediction, gold):
    # Optionally, normalize text for semantic similarity too.
    pred_norm = normalize_text(prediction)
    gold_norm = normalize_text(gold)
    pred_embedding = semantic_model.encode(pred_norm)
    gold_embedding = semantic_model.encode(gold_norm)
    cosine_sim = util.cos_sim(pred_embedding, gold_embedding).item()
    return cosine_sim

rouge = Rouge()

def compute_rouge(prediction, gold):
    pred_norm = normalize_text(prediction)
    gold_norm = normalize_text(gold)
    if not pred_norm or not gold_norm:
        return 0  # Skip ROUGE calculation for empty normalized text
    try:
        scores = rouge.get_scores(pred_norm, gold_norm)
        return scores[0]['rouge-l']['f']
    except ValueError as e:
        print(f"ROUGE computation failed: {e}")
        return 0  # Assign 0 if ROUGE computation fails


# Maximum BERT input size is 512 tokens; define chunking function with overlap
def chunk_text(text, tokenizer, max_tokens=512, overlap=50):
    tokens = tokenizer.encode(text, add_special_tokens=False)
    chunks = []
    start = 0
    while start < len(tokens):
        end = min(start + max_tokens, len(tokens))
        chunk_tokens = tokens[start:end]
        chunk = tokenizer.decode(chunk_tokens)
        chunks.append(chunk)
        start += max_tokens - overlap  # move the window with overlap
    return chunks


def build_tfidf_index(chunks):
    # Create a TF-IDF vectorizer and fit it on the chunks
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(chunks)
    return vectorizer, tfidf_matrix


def retrieve_top_k(query, vectorizer, tfidf_matrix, k=3):
    # Transform the query into a TF-IDF vector
    query_vec = vectorizer.transform([query])
    # Compute cosine similarity between the query and all chunks
    similarities = cosine_similarity(query_vec, tfidf_matrix)
    # Get indices of the top-k most similar chunks (in descending order)
    top_indices = similarities.argsort()[0][-k:][::-1]
    return top_indices, similarities[0][top_indices]


#---------------------------------------------------------------------------------------------------------------------------------------


# Run the Experiment

# { model_name: { category: [ { "Format": ..., "Question": ..., "Gold Answer": ..., "Model Answer": ..., metrics... }, ... ] } }

detailed_results = {}

use_chunking = True  # TF-IDF retrieval will be applied when chunking is enabled
top_k_chunks = 3     # Number of chunks to retrieve

for model_name, qa_model in models.items():
    detailed_results[model_name] = {}
    print(f"Running experiments for model: {model_name}")
    tokenizer = qa_model.tokenizer

    for ctx_item in tqdm(data["contexts"], desc="Contexts"):
        context_text = ctx_item["context"]
        # Split the context into chunks
        context_chunks = chunk_text(context_text, tokenizer, max_tokens=512, overlap=50)

        # Build a TF-IDF index for the chunks
        vectorizer, tfidf_matrix = build_tfidf_index(context_chunks)

        for category_dict in tqdm(ctx_item["Categories"], desc="Categories", leave=False):
            for cat_name, questions in category_dict.items():
                if cat_name not in detailed_results[model_name]:
                    detailed_results[model_name][cat_name] = []

                for q_obj in tqdm(questions, desc=f"Questions in {cat_name}", leave=False):
                    format_type = q_obj["Format"]
                    question_text = q_obj["Question"]
                    gold_answer = q_obj["Gold Answer"]

                    if use_chunking:
                        # Retrieve top-k relevant chunks for the current question
                        top_indices, sims = retrieve_top_k(question_text, vectorizer, tfidf_matrix, k=top_k_chunks)
                        # Option 1: Concatenate the top-k chunks into one context string
                        retrieved_context = " ".join([context_chunks[idx] for idx in top_indices])

                        # Run the QA model using the retrieved context
                        result = qa_model({"question": question_text, "context": retrieved_context})
                        if isinstance(result, dict):
                            model_answer = result.get("answer")
                            confidence = result.get("score", None)
                            start_logit = result.get("start_logit", None)
                            end_logit = result.get("end_logit", None)
                        else:
                            model_answer = result
                            confidence = None
                            start_logit = None
                            end_logit = None
                    else:
                        result = qa_model({"question": question_text, "context": context_text})
                        model_answer = result.get("answer") if isinstance(result, dict) else result
                        confidence = result.get("score", None)
                        start_logit = result.get("start_logit", None)
                        end_logit = result.get("end_logit", None)

                    # Compute evaluation metrics
                    em = compute_em(model_answer, gold_answer)
                    f1 = compute_f1(model_answer, gold_answer)
                    partial_f1 = compute_partial_f1(model_answer, gold_answer)
                    rouge_score = compute_rouge(model_answer, gold_answer)
                    semantic_sim = compute_semantic_similarity(model_answer, gold_answer)

                    detailed_results[model_name][cat_name].append({
                        "Format": format_type,
                        "Question": question_text,
                        "Gold Answer": gold_answer,
                        "Model Answer": model_answer,
                        "Confidence": confidence,
                        "Start Logit": start_logit,
                        "End Logit": end_logit,
                        "EM": em,
                        "F1": f1,
                        "Partial F1": partial_f1,
                        "ROUGE": rouge_score,
                        "Semantic Similarity": semantic_sim
                    })

# Save detailed results to a JSON file for further analysis
with open("detailed_experiment_5_results.json", "w") as outfile:
    json.dump(detailed_results, outfile, indent=2)


# Aggregate metrics by model and question format (across all contexts and categories)
aggregated_metrics = {}  # { model_name: { format: {metrics} } }

for model_name, cat_results in detailed_results.items():
    format_scores = {}
    for cat, results_list in cat_results.items():
        for entry in results_list:
            fmt = entry["Format"]
            if fmt not in format_scores:
                format_scores[fmt] = {"Confidence": [], "EM": [], "F1": [], "Partial F1": [], "ROUGE": [], "Semantic Similarity": []}
            format_scores[fmt]["Confidence"].append(entry["Confidence"])
            format_scores[fmt]["EM"].append(entry["EM"])
            format_scores[fmt]["F1"].append(entry["F1"])
            format_scores[fmt]["Partial F1"].append(entry["Partial F1"])
            format_scores[fmt]["ROUGE"].append(entry["ROUGE"])
            format_scores[fmt]["Semantic Similarity"].append(entry["Semantic Similarity"])
    aggregated_metrics[model_name] = {}
    for fmt, scores in format_scores.items():
        aggregated_metrics[model_name][fmt] = {
            "Avg Confidence": np.mean(scores["Confidence"]),
            "Avg EM": np.mean(scores["EM"]),
            "Avg F1": np.mean(scores["F1"]),
            "Avg Partial F1": np.mean(scores["Partial F1"]),
            "Avg ROUGE": np.mean(scores["ROUGE"]),
            "Avg Semantic Similarity": np.mean(scores["Semantic Similarity"])
        }

with open("Aggregated_experiment_5_results.json", "w") as outfile:
    json.dump(aggregated_metrics, outfile, indent=2)
# Out:
# True
# Tesla T4
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/436M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/556 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/222k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/702k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Device set to use cuda:0
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/496M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/79.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Device set to use cuda:0
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Running experiments for model: Jasu/legalbert
# Contexts:   0%|          | 0/3 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (7369 > 512). Running this sequence through the model will result in indexing errors
#
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in Establishment of Distributorship:   0%|          | 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/transformers/pipelines/question_answering.py:391: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(
#
#
# Questions in Establishment of Distributorship:  25%|██▌       | 1/4 [00:00<00:02,  1.09it/s]
#
# Questions in Establishment of Distributorship:  50%|█████     | 2/4 [00:01<00:00,  2.02it/s]
#
# Questions in Establishment of Distributorship:  75%|███████▌  | 3/4 [00:01<00:00,  2.94it/s]
#
# Questions in Establishment of Distributorship: 100%|██████████| 4/4 [00:01<00:00,  3.70it/s]
#
#
#
# Questions in Term of the Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Term of the Agreement:  25%|██▌       | 1/4 [00:00<00:00,  6.55it/s]
#
# Questions in Term of the Agreement:  50%|█████     | 2/4 [00:00<00:00,  6.17it/s]
#
# Questions in Term of the Agreement:  75%|███████▌  | 3/4 [00:00<00:00,  6.44it/s]
#
# Questions in Term of the Agreement: 100%|██████████| 4/4 [00:00<00:00,  6.29it/s]
#
#
#
# Questions in Minimum Purchase Requirements:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Minimum Purchase Requirements:  25%|██▌       | 1/4 [00:00<00:00,  6.51it/s]
#
# Questions in Minimum Purchase Requirements:  50%|█████     | 2/4 [00:00<00:00,  6.04it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#
#
# Questions in Minimum Purchase Requirements:  75%|███████▌  | 3/4 [00:00<00:00,  6.12it/s]
#
# Questions in Minimum Purchase Requirements: 100%|██████████| 4/4 [00:00<00:00,  6.08it/s]
#
#
#
# Questions in Warranty Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Warranty Terms:  25%|██▌       | 1/4 [00:00<00:00,  6.10it/s]
#
# Questions in Warranty Terms:  50%|█████     | 2/4 [00:00<00:00,  5.98it/s]
#
# Questions in Warranty Terms:  75%|███████▌  | 3/4 [00:00<00:00,  6.14it/s]
#
# Questions in Warranty Terms: 100%|██████████| 4/4 [00:00<00:00,  5.12it/s]
#
#
#
# Questions in Termination Conditions:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Termination Conditions:  25%|██▌       | 1/4 [00:00<00:00,  6.07it/s]
#
# Questions in Termination Conditions:  50%|█████     | 2/4 [00:00<00:00,  5.26it/s]
#
# Questions in Termination Conditions:  75%|███████▌  | 3/4 [00:00<00:00,  5.54it/s]
#
# Questions in Termination Conditions: 100%|██████████| 4/4 [00:01<00:00,  3.37it/s]
#
#
#
# Questions in Payment Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Payment Terms:  25%|██▌       | 1/4 [00:00<00:00,  5.84it/s]
#
# Questions in Payment Terms:  50%|█████     | 2/4 [00:00<00:00,  5.14it/s]
#
# Questions in Payment Terms:  75%|███████▌  | 3/4 [00:00<00:00,  5.50it/s]
#
# Questions in Payment Terms: 100%|██████████| 4/4 [00:00<00:00,  5.38it/s]
#
#
#
# Questions in Indemnification Obligations:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Indemnification Obligations:  25%|██▌       | 1/4 [00:00<00:00,  5.09it/s]
#
# Questions in Indemnification Obligations:  50%|█████     | 2/4 [00:00<00:00,  4.78it/s]
#
# Questions in Indemnification Obligations:  75%|███████▌  | 3/4 [00:00<00:00,  5.03it/s]
#
# Questions in Indemnification Obligations: 100%|██████████| 4/4 [00:00<00:00,  4.92it/s]
#
#
#
# Questions in Non-Disclosure Agreements:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Non-Disclosure Agreements:  25%|██▌       | 1/4 [00:00<00:00,  6.50it/s]
#
# Questions in Non-Disclosure Agreements:  50%|█████     | 2/4 [00:00<00:00,  5.87it/s]
#
# Questions in Non-Disclosure Agreements:  75%|███████▌  | 3/4 [00:00<00:00,  6.34it/s]
#
# Questions in Non-Disclosure Agreements: 100%|██████████| 4/4 [00:00<00:00,  6.16it/s]
#
#
#
# Questions in Relationship of Parties:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Relationship of Parties:  25%|██▌       | 1/4 [00:00<00:00,  6.41it/s]
#
# Questions in Relationship of Parties:  50%|█████     | 2/4 [00:00<00:00,  5.93it/s]
#
# Questions in Relationship of Parties:  75%|███████▌  | 3/4 [00:00<00:00,  6.17it/s]
#
# Questions in Relationship of Parties: 100%|██████████| 4/4 [00:00<00:00,  5.95it/s]
#
#
#
# Questions in License Grant:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in License Grant:  25%|██▌       | 1/4 [00:00<00:00,  6.02it/s]
#
# Questions in License Grant:  50%|█████     | 2/4 [00:00<00:00,  5.84it/s]
#
# Questions in License Grant:  75%|███████▌  | 3/4 [00:00<00:00,  6.06it/s]
#
# Questions in License Grant: 100%|██████████| 4/4 [00:00<00:00,  5.96it/s]
#
#
# Categories: 100%|██████████| 1/1 [00:08<00:00,  8.19s/it]
# Contexts:  33%|███▎      | 1/3 [00:08<00:16,  8.32s/it]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in License Grants and Restrictions:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in License Grants and Restrictions:  25%|██▌       | 1/4 [00:00<00:00,  6.13it/s]
#
# Questions in License Grants and Restrictions:  50%|█████     | 2/4 [00:00<00:00,  5.86it/s]
#
# Questions in License Grants and Restrictions:  75%|███████▌  | 3/4 [00:00<00:00,  6.03it/s]
#
# Questions in License Grants and Restrictions: 100%|██████████| 4/4 [00:00<00:00,  5.97it/s]
#
#
#
# Questions in Distribution and Other Obligations:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Distribution and Other Obligations:  25%|██▌       | 1/4 [00:00<00:00,  6.03it/s]
#
# Questions in Distribution and Other Obligations:  50%|█████     | 2/4 [00:00<00:00,  5.74it/s]
#
# Questions in Distribution and Other Obligations:  75%|███████▌  | 3/4 [00:00<00:00,  6.00it/s]
#
# Questions in Distribution and Other Obligations: 100%|██████████| 4/4 [00:00<00:00,  5.93it/s]
#
#
#
# Questions in Payment Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Payment Terms:  25%|██▌       | 1/4 [00:00<00:00,  6.55it/s]
#
# Questions in Payment Terms:  50%|█████     | 2/4 [00:00<00:00,  6.03it/s]
#
# Questions in Payment Terms:  75%|███████▌  | 3/4 [00:00<00:00,  6.15it/s]
#
# Questions in Payment Terms: 100%|██████████| 4/4 [00:00<00:00,  6.04it/s]
#
#
#
# Questions in Term and Termination:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Term and Termination:  25%|██▌       | 1/4 [00:00<00:00,  6.24it/s]
#
# Questions in Term and Termination:  50%|█████     | 2/4 [00:00<00:00,  5.90it/s]
#
# Questions in Term and Termination:  75%|███████▌  | 3/4 [00:00<00:00,  6.19it/s]
#
# Questions in Term and Termination: 100%|██████████| 4/4 [00:00<00:00,  6.04it/s]
#
#
#
# Questions in Confidential Information:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Confidential Information:  25%|██▌       | 1/4 [00:00<00:00,  6.41it/s]
#
# Questions in Confidential Information:  50%|█████     | 2/4 [00:00<00:00,  5.96it/s]
#
# Questions in Confidential Information:  75%|███████▌  | 3/4 [00:00<00:00,  5.96it/s]
#
# Questions in Confidential Information: 100%|██████████| 4/4 [00:00<00:00,  5.90it/s]
#
#
#
# Questions in Proprietary Rights:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Proprietary Rights:  25%|██▌       | 1/4 [00:00<00:00,  6.33it/s]
#
# Questions in Proprietary Rights:  50%|█████     | 2/4 [00:00<00:00,  5.85it/s]
#
# Questions in Proprietary Rights:  75%|███████▌  | 3/4 [00:00<00:00,  6.04it/s]
#
# Questions in Proprietary Rights: 100%|██████████| 4/4 [00:00<00:00,  5.80it/s]
#
#
#
# Questions in Warranties:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Warranties:  25%|██▌       | 1/4 [00:00<00:00,  5.72it/s]
#
# Questions in Warranties:  50%|█████     | 2/4 [00:00<00:00,  5.62it/s]
#
# Questions in Warranties:  75%|███████▌  | 3/4 [00:00<00:00,  5.96it/s]
#
# Questions in Warranties: 100%|██████████| 4/4 [00:00<00:00,  5.93it/s]
#
#
#
# Questions in Limitation of Liability:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Limitation of Liability:  25%|██▌       | 1/4 [00:00<00:00,  5.88it/s]
#
# Questions in Limitation of Liability:  50%|█████     | 2/4 [00:00<00:00,  5.58it/s]
#
# Questions in Limitation of Liability:  75%|███████▌  | 3/4 [00:00<00:00,  5.88it/s]
#
# Questions in Limitation of Liability: 100%|██████████| 4/4 [00:00<00:00,  5.84it/s]
#
#
#
# Questions in Indemnification:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Indemnification:  25%|██▌       | 1/4 [00:00<00:00,  6.03it/s]
#
# Questions in Indemnification:  50%|█████     | 2/4 [00:00<00:00,  5.68it/s]
#
# Questions in Indemnification:  75%|███████▌  | 3/4 [00:00<00:00,  5.63it/s]
#
# Questions in Indemnification: 100%|██████████| 4/4 [00:00<00:00,  5.71it/s]
#
#
#
# Questions in General:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in General:  25%|██▌       | 1/4 [00:00<00:00,  6.60it/s]
#
# Questions in General:  50%|█████     | 2/4 [00:00<00:00,  6.18it/s]
#
# Questions in General:  75%|███████▌  | 3/4 [00:00<00:00,  6.31it/s]
#
# Questions in General: 100%|██████████| 4/4 [00:00<00:00,  6.11it/s]
#
#
# Categories: 100%|██████████| 1/1 [00:06<00:00,  6.91s/it]
# Contexts:  67%|██████▋   | 2/3 [00:15<00:07,  7.60s/it]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in Filing Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Filing Agreement:  75%|███████▌  | 3/4 [00:00<00:00, 28.69it/s]
#
#
#
# Questions in Regulatory Compliance:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Regulatory Compliance:  75%|███████▌  | 3/4 [00:00<00:00, 22.91it/s]
#
#
#
# Questions in Filing Responsibility:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Filing Responsibility: 100%|██████████| 4/4 [00:00<00:00, 32.66it/s]
#
#
#
# Questions in Accuracy of Information:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Accuracy of Information:  75%|███████▌  | 3/4 [00:00<00:00, 26.77it/s]
#
#
#
# Questions in Date of Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Date of Agreement: 100%|██████████| 4/4 [00:00<00:00, 32.20it/s]
#
#
#
# Questions in Signatories:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Signatories:  75%|███████▌  | 3/4 [00:00<00:00, 24.12it/s]
#
#
# Categories: 100%|██████████| 1/1 [00:00<00:00,  1.03it/s]
# Contexts: 100%|██████████| 3/3 [00:16<00:00,  5.47s/it]
# Running experiments for model: deepset/roberta-squad2
# Contexts:   0%|          | 0/3 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (23248 > 512). Running this sequence through the model will result in indexing errors
#
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in Establishment of Distributorship:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Establishment of Distributorship:  25%|██▌       | 1/4 [00:00<00:00,  4.41it/s]
#
# Questions in Establishment of Distributorship:  50%|█████     | 2/4 [00:00<00:00,  4.77it/s]
#
# Questions in Establishment of Distributorship:  75%|███████▌  | 3/4 [00:00<00:00,  5.27it/s]
#
# Questions in Establishment of Distributorship: 100%|██████████| 4/4 [00:00<00:00,  5.78it/s]
#
#
#
# Questions in Term of the Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Term of the Agreement:  25%|██▌       | 1/4 [00:00<00:00,  6.19it/s]
#
# Questions in Term of the Agreement:  50%|█████     | 2/4 [00:00<00:00,  5.65it/s]
#
# Questions in Term of the Agreement:  75%|███████▌  | 3/4 [00:00<00:00,  5.56it/s]
#
# Questions in Term of the Agreement: 100%|██████████| 4/4 [00:00<00:00,  5.41it/s]
#
#
#
# Questions in Minimum Purchase Requirements:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Minimum Purchase Requirements:  25%|██▌       | 1/4 [00:00<00:00,  5.82it/s]
#
# Questions in Minimum Purchase Requirements:  50%|█████     | 2/4 [00:00<00:00,  5.03it/s]
#
# Questions in Minimum Purchase Requirements:  75%|███████▌  | 3/4 [00:00<00:00,  5.39it/s]
#
# Questions in Minimum Purchase Requirements: 100%|██████████| 4/4 [00:00<00:00,  5.59it/s]
#
#
#
# Questions in Warranty Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Warranty Terms:  25%|██▌       | 1/4 [00:00<00:00,  6.62it/s]
#
# Questions in Warranty Terms:  50%|█████     | 2/4 [00:00<00:00,  6.13it/s]
#
# Questions in Warranty Terms:  75%|███████▌  | 3/4 [00:00<00:00,  6.27it/s]
#
# Questions in Warranty Terms: 100%|██████████| 4/4 [00:04<00:00,  1.87s/it]
#
#
#
# Questions in Termination Conditions:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Termination Conditions:  25%|██▌       | 1/4 [00:00<00:00,  6.63it/s]
#
# Questions in Termination Conditions:  50%|█████     | 2/4 [00:00<00:00,  6.00it/s]
#
# Questions in Termination Conditions:  75%|███████▌  | 3/4 [00:00<00:00,  6.31it/s]
#
# Questions in Termination Conditions: 100%|██████████| 4/4 [00:00<00:00,  3.68it/s]
#
#
#
# Questions in Payment Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Payment Terms:  25%|██▌       | 1/4 [00:00<00:00,  6.77it/s]
#
# Questions in Payment Terms:  50%|█████     | 2/4 [00:00<00:00,  6.10it/s]
#
# Questions in Payment Terms:  75%|███████▌  | 3/4 [00:00<00:00,  6.29it/s]
#
# Questions in Payment Terms: 100%|██████████| 4/4 [00:00<00:00,  6.12it/s]
#
#
#
# Questions in Indemnification Obligations:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Indemnification Obligations:  25%|██▌       | 1/4 [00:00<00:00,  5.84it/s]
#
# Questions in Indemnification Obligations:  50%|█████     | 2/4 [00:00<00:00,  5.70it/s]
#
# Questions in Indemnification Obligations:  75%|███████▌  | 3/4 [00:00<00:00,  5.92it/s]
#
# Questions in Indemnification Obligations: 100%|██████████| 4/4 [00:00<00:00,  5.84it/s]
#
#
#
# Questions in Non-Disclosure Agreements:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Non-Disclosure Agreements:  25%|██▌       | 1/4 [00:00<00:01,  2.47it/s]
#
# Questions in Non-Disclosure Agreements:  50%|█████     | 2/4 [00:00<00:00,  2.76it/s]
#
# Questions in Non-Disclosure Agreements:  75%|███████▌  | 3/4 [00:00<00:00,  3.37it/s]
#
# Questions in Non-Disclosure Agreements: 100%|██████████| 4/4 [00:01<00:00,  4.09it/s]
#
#
#
# Questions in Relationship of Parties:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Relationship of Parties:  25%|██▌       | 1/4 [00:00<00:00,  3.53it/s]
#
# Questions in Relationship of Parties:  50%|█████     | 2/4 [00:00<00:00,  2.61it/s]
#
# Questions in Relationship of Parties:  75%|███████▌  | 3/4 [00:00<00:00,  3.16it/s]
#
# Questions in Relationship of Parties: 100%|██████████| 4/4 [00:01<00:00,  3.87it/s]
#
#
#
# Questions in License Grant:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in License Grant:  25%|██▌       | 1/4 [00:00<00:00,  6.45it/s]
#
# Questions in License Grant:  50%|█████     | 2/4 [00:00<00:01,  1.86it/s]
#
# Questions in License Grant:  75%|███████▌  | 3/4 [00:01<00:00,  1.76it/s]
#
# Questions in License Grant: 100%|██████████| 4/4 [00:01<00:00,  2.39it/s]
#
#
# Categories: 100%|██████████| 1/1 [00:13<00:00, 13.59s/it]
# Contexts:  33%|███▎      | 1/3 [00:14<00:28, 14.05s/it]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in License Grants and Restrictions:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in License Grants and Restrictions:  25%|██▌       | 1/4 [00:00<00:00,  5.38it/s]
#
# Questions in License Grants and Restrictions:  50%|█████     | 2/4 [00:00<00:00,  4.84it/s]
#
# Questions in License Grants and Restrictions:  75%|███████▌  | 3/4 [00:00<00:00,  5.03it/s]
#
# Questions in License Grants and Restrictions: 100%|██████████| 4/4 [00:00<00:00,  5.07it/s]
#
#
#
# Questions in Distribution and Other Obligations:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Distribution and Other Obligations:  25%|██▌       | 1/4 [00:00<00:00,  5.72it/s]
#
# Questions in Distribution and Other Obligations:  50%|█████     | 2/4 [00:00<00:00,  5.27it/s]
#
# Questions in Distribution and Other Obligations:  75%|███████▌  | 3/4 [00:00<00:00,  5.35it/s]
#
# Questions in Distribution and Other Obligations: 100%|██████████| 4/4 [00:00<00:00,  5.48it/s]
#
#
#
# Questions in Payment Terms:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Payment Terms:  25%|██▌       | 1/4 [00:00<00:00,  6.23it/s]
#
# Questions in Payment Terms:  50%|█████     | 2/4 [00:00<00:00,  5.78it/s]
#
# Questions in Payment Terms:  75%|███████▌  | 3/4 [00:00<00:00,  6.02it/s]
#
# Questions in Payment Terms: 100%|██████████| 4/4 [00:00<00:00,  5.88it/s]
#
#
#
# Questions in Term and Termination:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Term and Termination:  25%|██▌       | 1/4 [00:00<00:00,  6.24it/s]
#
# Questions in Term and Termination:  50%|█████     | 2/4 [00:00<00:00,  5.54it/s]
#
# Questions in Term and Termination:  75%|███████▌  | 3/4 [00:00<00:00,  5.93it/s]
#
# Questions in Term and Termination: 100%|██████████| 4/4 [00:00<00:00,  5.82it/s]
#
#
#
# Questions in Confidential Information:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Confidential Information:  25%|██▌       | 1/4 [00:00<00:00,  6.08it/s]
#
# Questions in Confidential Information:  50%|█████     | 2/4 [00:00<00:00,  5.57it/s]
#
# Questions in Confidential Information:  75%|███████▌  | 3/4 [00:00<00:00,  5.79it/s]
#
# Questions in Confidential Information: 100%|██████████| 4/4 [00:00<00:00,  5.71it/s]
#
#
#
# Questions in Proprietary Rights:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Proprietary Rights:  25%|██▌       | 1/4 [00:00<00:00,  5.90it/s]
#
# Questions in Proprietary Rights:  50%|█████     | 2/4 [00:00<00:00,  5.29it/s]
#
# Questions in Proprietary Rights:  75%|███████▌  | 3/4 [00:00<00:00,  5.60it/s]
#
# Questions in Proprietary Rights: 100%|██████████| 4/4 [00:00<00:00,  5.57it/s]
#
#
#
# Questions in Warranties:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Warranties:  25%|██▌       | 1/4 [00:00<00:00,  6.00it/s]
#
# Questions in Warranties:  50%|█████     | 2/4 [00:00<00:00,  5.76it/s]
#
# Questions in Warranties:  75%|███████▌  | 3/4 [00:00<00:00,  5.95it/s]
#
# Questions in Warranties: 100%|██████████| 4/4 [00:00<00:00,  5.85it/s]
#
#
#
# Questions in Limitation of Liability:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Limitation of Liability:  25%|██▌       | 1/4 [00:00<00:00,  6.41it/s]
#
# Questions in Limitation of Liability:  50%|█████     | 2/4 [00:00<00:00,  5.88it/s]
#
# Questions in Limitation of Liability:  75%|███████▌  | 3/4 [00:00<00:00,  5.99it/s]
#
# Questions in Limitation of Liability: 100%|██████████| 4/4 [00:00<00:00,  5.91it/s]
#
#
#
# Questions in Indemnification:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Indemnification:  25%|██▌       | 1/4 [00:00<00:00,  5.89it/s]
#
# Questions in Indemnification:  50%|█████     | 2/4 [00:00<00:00,  5.56it/s]
#
# Questions in Indemnification:  75%|███████▌  | 3/4 [00:00<00:00,  5.81it/s]
#
# Questions in Indemnification: 100%|██████████| 4/4 [00:00<00:00,  5.72it/s]
#
#
#
# Questions in General:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in General:  25%|██▌       | 1/4 [00:00<00:00,  6.04it/s]
#
# Questions in General:  50%|█████     | 2/4 [00:00<00:00,  5.60it/s]
#
# Questions in General:  75%|███████▌  | 3/4 [00:00<00:00,  5.85it/s]
#
# Questions in General: 100%|██████████| 4/4 [00:00<00:00,  5.70it/s]
#
#
# Categories: 100%|██████████| 1/1 [00:07<00:00,  7.23s/it]
# Contexts:  67%|██████▋   | 2/3 [00:21<00:10, 10.23s/it]
# Categories:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Questions in Filing Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Filing Agreement:  75%|███████▌  | 3/4 [00:00<00:00, 29.40it/s]
#
#
#
# Questions in Regulatory Compliance:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Regulatory Compliance:  75%|███████▌  | 3/4 [00:00<00:00, 29.94it/s]
#
#
#
# Questions in Filing Responsibility:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Filing Responsibility:  75%|███████▌  | 3/4 [00:00<00:00, 28.45it/s]
#
#
#
# Questions in Accuracy of Information:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Accuracy of Information:  75%|███████▌  | 3/4 [00:00<00:00, 24.14it/s]
#
#
#
# Questions in Date of Agreement:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Date of Agreement:  75%|███████▌  | 3/4 [00:00<00:00, 25.37it/s]
#
#
#
# Questions in Signatories:   0%|          | 0/4 [00:00<?, ?it/s]
#
# Questions in Signatories:  75%|███████▌  | 3/4 [00:00<00:00, 28.18it/s]
#
#
# Categories: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
# Contexts: 100%|██████████| 3/3 [00:22<00:00,  7.55s/it]
